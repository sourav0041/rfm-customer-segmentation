# %%
import pandas as pd

# %%
jupyter nbconvert --execute --to pdf notebook.ipynb
# Out:
#   File "C:\Users\soura\AppData\Local\Temp/ipykernel_16276/2588019851.py", line 1
#     jupyter nbconvert --execute --to pdf notebook.ipynb
#             ^
# SyntaxError: invalid syntax

# %%
pip install  pandoc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Pyppeteer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install notebook-as-pdf
# Out:
# ...
#   Using cached websockets-10.3-cp39-cp39-win_amd64.whl (98 kB)
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 8.1
#     Uninstalling websockets-8.1:
#       Successfully uninstalled websockets-8.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade --user nbconvert
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("C:\\Users\\soura\\Downloads\\Assignment round PS.xlsx")

# %%
df.columns = [c.replace(' ', '_') for c in df.columns]

# %%
df.drop(columns=['Billing_Province','Shipping_Province','Notes','Note_Attributes','Cancelled_at','Employee','Location','Device_ID','Tags','Tax_1_Name','Tax_1_Value','Tax_2_Name','Tax_2_Value','Tax_3_Name','Tax_3_Value','Tax_4_Name','Tax_4_Value','Tax_5_Name','Tax_5_Value','Phone','Receipt_Number','Discount_Code'],inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Name                            0.000000
# Financial_Status               19.693860
# Paid_at                        20.965517
# Fulfillment_Status             19.693860
# Fulfilled_at                   28.305299
# Accepts_Marketing              19.693860
# Currency                       19.693860
# Subtotal                       19.693860
# Shipping                       19.693860
# Taxes                          19.693860
# Total                          19.693860
# Discount_Amount                19.693860
# Shipping_Method                19.693860
# Created_at                      0.000000
# Lineitem_quantity               0.000000
# Lineitem_name                   0.000000
# Lineitem_price                  0.000000
# Lineitem_compare_at_price      18.240538
# Lineitem_sku                    0.000000
# Lineitem_requires_shipping      0.000000
# Lineitem_taxable                0.000000
# Lineitem_fulfillment_status     0.000000
# Billing_Zip                    19.734230
# ...

# %%
df.dropna(subset=['Total'], inplace=True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Name                            0.000000
# Financial_Status                0.000000
# Paid_at                         1.583511
# Fulfillment_Status              0.000000
# Fulfilled_at                   10.723263
# Accepts_Marketing               0.000000
# Currency                        0.000000
# Subtotal                        0.000000
# Shipping                        0.000000
# Taxes                           0.000000
# Total                           0.000000
# Discount_Amount                 0.000000
# Shipping_Method                 0.000000
# Created_at                      0.000000
# Lineitem_quantity               0.000000
# Lineitem_name                   0.000000
# Lineitem_price                  0.000000
# Lineitem_compare_at_price      18.874366
# Lineitem_sku                    0.000000
# Lineitem_requires_shipping      0.000000
# Lineitem_taxable                0.000000
# Lineitem_fulfillment_status     0.000000
# Billing_Zip                     0.050270
# ...

# %%
df.shape
# Out:
# (95484, 35)

# %%
df.describe()
# Out:
#            Subtotal      Shipping         Taxes         Total  \
# count  95484.000000  95484.000000  95484.000000  95484.000000
# mean      58.810728      0.064269      9.809089     58.872480
# std       66.109370      0.829832     11.036311     66.217577
# min        0.000000      0.000000      0.000000      0.000000
# 25%       22.400000      0.000000      3.750000     22.500000
# 50%       35.990000      0.000000      6.000000     36.000000
# 75%       72.000000      0.000000     12.000000     72.000000
# max     1952.900000     36.000000    325.480000   1952.900000
#
#        Discount_Amount  Lineitem_quantity  Lineitem_price  \
# count     95484.000000       95484.000000    95484.000000
# mean         10.253376           1.027827       55.823520
# std          16.057415           0.278898       61.747689
# min           0.000000           1.000000        0.000000
# 25%           0.000000           1.000000       24.990000
# ...

# %%
df['Lineitem_compare_at_price'].fillna(df['Lineitem_compare_at_price'].median(skipna=True),inplace= True)

# %%
df.isnull().sum()/len(df)*100
# Out:
# Name                            0.000000
# Financial_Status                0.000000
# Paid_at                         1.583511
# Fulfillment_Status              0.000000
# Fulfilled_at                   10.723263
# Accepts_Marketing               0.000000
# Currency                        0.000000
# Subtotal                        0.000000
# Shipping                        0.000000
# Taxes                           0.000000
# Total                           0.000000
# Discount_Amount                 0.000000
# Shipping_Method                 0.000000
# Created_at                      0.000000
# Lineitem_quantity               0.000000
# Lineitem_name                   0.000000
# Lineitem_price                  0.000000
# Lineitem_compare_at_price       0.000000
# Lineitem_sku                    0.000000
# Lineitem_requires_shipping      0.000000
# Lineitem_taxable                0.000000
# Lineitem_fulfillment_status     0.000000
# Billing_Zip                     0.050270
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95484 entries, 0 to 118899
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         95484 non-null  object
#  1   Financial_Status             95484 non-null  object
#  2   Paid_at                      93972 non-null  object
#  3   Fulfillment_Status           95484 non-null  object
#  4   Fulfilled_at                 85245 non-null  object
#  5   Accepts_Marketing            95484 non-null  object
#  6   Currency                     95484 non-null  object
#  7   Subtotal                     95484 non-null  float64
#  8   Shipping                     95484 non-null  float64
#  9   Taxes                        95484 non-null  float64
#  10  Total                        95484 non-null  float64
#  11  Discount_Amount              95484 non-null  float64
# ...

# %%
df.head()
# Out:
#      Name Financial_Status                    Paid_at Fulfillment_Status  \
# 0  #96568             paid  2020-10-12 14:22:07 +0100        unfulfilled
# 1  #96567             paid  2020-10-12 14:17:46 +0100        unfulfilled
# 2  #96566             paid  2020-10-12 14:11:13 +0100        unfulfilled
# 4  #96565             paid  2020-10-12 14:05:34 +0100        unfulfilled
# 5  #96564             paid  2020-10-12 13:56:33 +0100        unfulfilled
#
#   Fulfilled_at Accepts_Marketing Currency  Subtotal  Shipping  Taxes  ...  \
# 0          NaN                no      GBP      9.99       0.0   1.67  ...
# 1          NaN                no      GBP    179.99       0.0  30.00  ...
# 2          NaN                no      GBP     71.99       0.0  12.00  ...
# 4          NaN                no      GBP     14.99       0.0   2.50  ...
# 5          NaN                no      GBP     28.00       0.0   4.67  ...
#
#    Shipping_Country             Payment_Method  Payment_Reference  \
# ...

# %%
df.dropna()
df.head()
# Out:
#      Name Financial_Status                    Paid_at Fulfillment_Status  \
# 0  #96568             paid  2020-10-12 14:22:07 +0100        unfulfilled
# 1  #96567             paid  2020-10-12 14:17:46 +0100        unfulfilled
# 2  #96566             paid  2020-10-12 14:11:13 +0100        unfulfilled
# 4  #96565             paid  2020-10-12 14:05:34 +0100        unfulfilled
# 5  #96564             paid  2020-10-12 13:56:33 +0100        unfulfilled
#
#   Fulfilled_at Accepts_Marketing Currency  Subtotal  Shipping  Taxes  ...  \
# 0          NaN                no      GBP      9.99       0.0   1.67  ...
# 1          NaN                no      GBP    179.99       0.0  30.00  ...
# 2          NaN                no      GBP     71.99       0.0  12.00  ...
# 4          NaN                no      GBP     14.99       0.0   2.50  ...
# 5          NaN                no      GBP     28.00       0.0   4.67  ...
#
#    Shipping_Country             Payment_Method  Payment_Reference  \
# ...

# %%
df.describe()
# Out:
#            Subtotal      Shipping         Taxes         Total  \
# count  95484.000000  95484.000000  95484.000000  95484.000000
# mean      58.810728      0.064269      9.809089     58.872480
# std       66.109370      0.829832     11.036311     66.217577
# min        0.000000      0.000000      0.000000      0.000000
# 25%       22.400000      0.000000      3.750000     22.500000
# 50%       35.990000      0.000000      6.000000     36.000000
# 75%       72.000000      0.000000     12.000000     72.000000
# max     1952.900000     36.000000    325.480000   1952.900000
#
#        Discount_Amount  Lineitem_quantity  Lineitem_price  \
# count     95484.000000       95484.000000    95484.000000
# mean         10.253376           1.027827       55.823520
# std          16.057415           0.278898       61.747689
# min           0.000000           1.000000        0.000000
# 25%           0.000000           1.000000       24.990000
# ...

# %%
df.dropna()
df.shape
# Out:
# (95484, 35)

# %%
df[['Date','Time','Drop']] = df.Paid_at.str.split(" ",expand=True)
df.drop(columns=['Drop'],inplace=True)

# %%
df[['Created_Date','Created_Time','C_Drop']] = df.Created_at.str.split(" ",expand=True)
df.drop(columns=['C_Drop'],inplace=True)

# %%
df['Created_Date']=pd.to_datetime(df['Created_Date'])
df['Created_Date']=df['Created_Date'].dt.strftime('%d-%m-%Y')

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Date']=df['Date'].dt.strftime('%d-%m-%Y')

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95484 entries, 0 to 118899
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         95484 non-null  object
#  1   Financial_Status             95484 non-null  object
#  2   Paid_at                      93972 non-null  object
#  3   Fulfillment_Status           95484 non-null  object
#  4   Fulfilled_at                 85245 non-null  object
#  5   Accepts_Marketing            95484 non-null  object
#  6   Currency                     95484 non-null  object
#  7   Subtotal                     95484 non-null  float64
#  8   Shipping                     95484 non-null  float64
#  9   Taxes                        95484 non-null  float64
#  10  Total                        95484 non-null  float64
#  11  Discount_Amount              95484 non-null  float64
# ...

# %%
df_t_month=df.groupby('month').sum()['Total'].reset_index()

# %%
plt.figure(figsize=(10,6))
plt.plot(df_t_month["month"], df_t_month["Total"])

# %%
plt.figure(figsize=(10,6))
sns.barplot(df_t_month["month"],df_t_month["Total"])
# Out:
# C:\Users\soura\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='month', ylabel='Total'>

# %%
##############

# %%
df.head()
# Out:
#      Name Financial_Status                    Paid_at Fulfillment_Status  \
# 0  #96568             paid  2020-10-12 14:22:07 +0100        unfulfilled
# 1  #96567             paid  2020-10-12 14:17:46 +0100        unfulfilled
# 2  #96566             paid  2020-10-12 14:11:13 +0100        unfulfilled
# 4  #96565             paid  2020-10-12 14:05:34 +0100        unfulfilled
# 5  #96564             paid  2020-10-12 13:56:33 +0100        unfulfilled
#
#   Fulfilled_at Accepts_Marketing Currency  Subtotal  Shipping  Taxes  ...  \
# 0          NaN                no      GBP      9.99       0.0   1.67  ...
# 1          NaN                no      GBP    179.99       0.0  30.00  ...
# 2          NaN                no      GBP     71.99       0.0  12.00  ...
# 4          NaN                no      GBP     14.99       0.0   2.50  ...
# 5          NaN                no      GBP     28.00       0.0   4.67  ...
#
#    Outstanding_Balance            Id Risk_Level Source  Lineitem_discount  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Financial_Status', 'Paid_at', 'Fulfillment_Status',
#        'Fulfilled_at', 'Accepts_Marketing', 'Currency', 'Subtotal', 'Shipping',
#        'Taxes', 'Total', 'Discount_Amount', 'Shipping_Method', 'Created_at',
#        'Lineitem_quantity', 'Lineitem_name', 'Lineitem_price',
#        'Lineitem_compare_at_price', 'Lineitem_sku',
#        'Lineitem_requires_shipping', 'Lineitem_taxable',
#        'Lineitem_fulfillment_status', 'Billing_Zip', 'Billing_Country',
#        'Shipping_Zip', 'Shipping_Country', 'Payment_Method',
#        'Payment_Reference', 'Refunded_Amount', 'Vendor', 'Outstanding_Balance',
#        'Id', 'Risk_Level', 'Source', 'Lineitem_discount', 'Date', 'Time',
#        'Created_Date', 'Created_Time', 'month'],
#       dtype='object')

# %%
Product_Sales=pd.DataFrame(df.groupby('Lineitem_name').sum()['Total'])

# %%
Product_Sales=Product_Sales.sort_values('Total',ascending=False)

# %%
Product_Sales[:10]
# Out:
#                                                         Total
# Lineitem_name
# Focus1 HyperClean Cordless 3-in-1 Vacuum - Ligh...  389907.04
# Focus1 PowerPlush Turbo Cordless 3-in-1 Vacuum ...  250937.61
# Focus1 HyperClean Cordless 3-in-1 Vacuum - Ligh...  178482.49
# Focus1 Handheld Garment Steamer - Purple - SI12...  119298.56
# Focus1 Portable Garment Steamer - Grey              113225.28
# Focus1 TurboPower Pet Extend Upright Vacuum - B...   99104.71
# Focus1 PowerPlush Turbo Cordless 3-in-1 Vacuum ...   88943.44
# Focus1 PowerTurbo Cordless 3-in-1 Vacuum - Grey...   69737.75
# Focus1 20L Nordic Digital Microwave - Slate Gre...   65431.55
# Focus1 MultiClean Pet Bagless Cylinder Vacuum -...   62814.22

# %%
df['Lineitem_quantity'].value_counts()
# Out:
# 1.0     93397
# 2.0      1859
# 3.0       134
# 4.0        43
# 5.0        12
# 7.0        10
# 6.0         9
# 8.0         5
# 10.0        3
# 15.0        3
# 14.0        2
# 20.0        2
# 37.0        1
# 11.0        1
# 12.0        1
# 16.0        1
# 9.0         1
# Name: Lineitem_quantity, dtype: int64

# %%
Most_sell_pro=pd.DataFrame(df.groupby("Lineitem_name").sum()['Lineitem_quantity'])

# %%
Most_sell_pro=Most_sell_pro.sort_values('Lineitem_quantity', ascending=False)

# %%
Most_sell_pro[:10]
# Out:
#                                                     Lineitem_quantity
# Lineitem_name
# Focus1 Handheld Garment Steamer - Purple - SI12...             4740.0
# Focus1 Portable Garment Steamer - Grey                         3823.0
# Focus1 HyperClean Cordless 3-in-1 Vacuum - Ligh...             2470.0
# Focus1 Egg Boiler and Poacher - Stainless Steel...             2453.0
# Focus1 Anti Calc Cartridge - None - SI9030N001                 2205.0
# Focus1 PowerPlush Turbo Cordless 3-in-1 Vacuum ...             1982.0
# Focus1 Anti Calc Cartridge - None - SI11010N001                1870.0
# Focus1 Chrome Dish Rack - Chrome                               1838.0
# Focus1 Handheld Garment Steamer - Purple                       1801.0
# Focus1 Egg Boiler and Poacher - Stainless Steel                1532.0

# %%
#####

# %%
sns.countplot(df['Shipping_Method'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\soura\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.Name.value_counts().sort_values(ascending=False)[:10]
# Out:
# #96568    1
# #96556    1
# #96565    1
# #96564    1
# #96563    1
# #96562    1
# #96561    1
# #96560    1
# #96559    1
# #96558    1
# Name: Name, dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                               0
# Financial_Status                   0
# Paid_at                         1512
# Fulfillment_Status                 0
# Fulfilled_at                   10239
# Accepts_Marketing                  0
# Currency                           0
# Subtotal                           0
# Shipping                           0
# Taxes                              0
# Total                              0
# Discount_Amount                    0
# Shipping_Method                    0
# Created_at                         0
# Lineitem_quantity                  0
# Lineitem_name                      0
# Lineitem_price                     0
# Lineitem_compare_at_price          0
# Lineitem_sku                       0
# Lineitem_requires_shipping         0
# Lineitem_taxable                   0
# Lineitem_fulfillment_status        0
# Billing_Zip                       48
# Billing_Country                    1
# Shipping_Zip                       0
# ...

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
sns.lineplot(x='Year', y='Total')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11320/1636572638.py in <module>
# ----> 1 sns.lineplot(x='Year', y='Total')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     690
#     691     variables = _LinePlotter.get_semantics(locals())
# --> 692     p = _LinePlotter(
#     693         data=data, variables=variables,
# ...

# %%
df.plot(x='Date', y='Total', figsize=(15,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(x='Date', y='Total', figsize=(12,6))
x_cor = ['2016-01-01','2017-01-01', '2018-01-01', '2019-01-01', '2020-01-01',
          '2021-01-01']
for i in x_cor:
    plt.axvline(x=i, color='black', linestyle='--')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('seasonality')
plt.show()

# %%
How many products are being sold
#this much product are sold in this time gap and total sales
# Out:
#   File "C:\Users\soura\AppData\Local\Temp/ipykernel_11320/3879810314.py", line 1
#     How many products are being sold
#         ^
# SyntaxError: invalid syntax

# %%
df['Lineitem_quantity'].sum()

# %%
df['Date'].min()
# Out:
# Timestamp('2016-01-04 00:00:00')

# %%
df['Date'].max()

# %%
df['Total'].sum().round(2)
# Out:
# 5621379.92

# %%
df['Discount_Amount'].sum()
# Out:
# 979033.4000000001

# %%
df['Lineitem_price'].sum()
# Out:
# 5330253.000000001

# %%
(df['Total'].sum()-df['Lineitem_price'].sum()).round(2)
# Out:
# 291126.92

# %%
df['Id'].value_counts()
# Out:
# 2.519080e+12    53
# 2.519060e+12    46
# 2.519160e+12    38
# 2.519070e+12    38
# 1.795060e+12    37
#                 ..
# 1.977410e+12     1
# 1.977400e+12     1
# 1.977380e+12     1
# 1.977370e+12     1
# 2.739127e+09     1
# Name: Id, Length: 58035, dtype: int64

# %%
n_df=df[df['Id'].duplicated(keep=False)]
n_df['Lineitem_name']=
# Out:
#   File "C:\Users\soura\AppData\Local\Temp/ipykernel_14332/460172171.py", line 2
#     n_df['Lineitem_name']=
#                           ^
# SyntaxError: invalid syntax

# %%
df['Billing_Zip'].value_counts()[:10]
# Out:
# BT36 4PE    72
# WF2 8TR     48
# AL10 9WN    33
# BT364PE     27
# TW27HY      25
# BS24 7GL    18
# BT36 4LB    18
# ME7 4NG     15
# WR3 8PZ     14
# EX8 4LR     13
# Name: Billing_Zip, dtype: int64

# %%
pd.DataFrame(df.groupby('Name').sum()['Total'])
# Out:
#          Total
# Name
# #10000   14.99
# #10001   89.99
# #10002   14.99
# #10003   14.99
# #10004   69.99
# ...        ...
# #9995    34.99
# #9996   109.98
# #9997     9.99
# #9998   154.99
# #9999    24.99
#
# [95484 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95484 entries, 0 to 118899
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         95484 non-null  object
#  1   Financial_Status             95484 non-null  object
#  2   Paid_at                      93972 non-null  object
#  3   Fulfillment_Status           95484 non-null  object
#  4   Fulfilled_at                 85245 non-null  object
#  5   Accepts_Marketing            95484 non-null  object
#  6   Currency                     95484 non-null  object
#  7   Subtotal                     95484 non-null  float64
#  8   Shipping                     95484 non-null  float64
#  9   Taxes                        95484 non-null  float64
#  10  Total                        95484 non-null  float64
#  11  Discount_Amount              95484 non-null  float64
# ...

# %%
print(df['Date'].max())
# Out:
# 2020-12-10 00:00:00

# %%
df_t_montf=df.groupby('month').sum()['Lineitem_quantity'].reset_index()

# %%
df_t_montf
# Out:
#     month  Lineitem_quantity
# 0     1.0             6735.0
# 1     2.0             6273.0
# 2     3.0             7795.0
# 3     4.0             9063.0
# 4     5.0             9462.0
# 5     6.0             8477.0
# 6     7.0             9377.0
# 7     8.0            10538.0
# 8     9.0             9166.0
# 9    10.0             5370.0
# 10   11.0             7692.0
# 11   12.0             6612.0

# %% [markdown]
#  <h3> PIE <h3/>

# %%
Payment_Method=pd.DataFrame(df.groupby('Payment_Method').count()['Name'])

# %%
Payment_Method
# Out:
#                                                      Name
# Payment_Method
# External Debit                                          1
# Pay over time with Klarna                            6898
# PayPal Express Checkout                             38394
# PayPal Express Checkout + Pay over time with Kl...      5
# PayPal Express Checkout + PayPal Payments Standard     22
# PayPal Express Checkout + Shopify Payments             54
# PayPal Express Checkout + manual                        2
# Shopify Payments                                    49447
# Shopify Payments + Pay over time with Klarna           73
# Shopify Payments + PayPal Express Checkout            568

# %%
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=None, data=None)>

# %%
#---------------------------------------------------------#

# %%
df_recency = df.groupby(by='Name',
                        as_index=False)['Order Date'].max()
df_recency.columns = ['Name', 'Date']
recent_date = df_recency['Date'].max()
df_recency['Recency'] = df_recency['Date'].apply(
    lambda x: (recent_date - x).days)
df_recency.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14332/3932033208.py in <module>
# ----> 1 df_recency = df.groupby(by='Name',
#       2                         as_index=False)['Order Date'].max()
#       3 df_recency.columns = ['Name', 'Date']
#       4 recent_date = df_recency['Date'].max()
#       5 df_recency['Recency'] = df_recency['Date'].apply(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1536                 stacklevel=2,
#    1537             )
# -> 1538         return super().__getitem__(key)
#    1539
#    1540     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     225         elif not getattr(self, "as_index", False):
#     226             if key not in self.obj.columns:
# ...

# %%
df['Created_Date'] = pd.to_datetime(df['Created_Date'])

# %%
df_recency = df.groupby(by='Name',
                        as_index=False)['Created_Date'].max()
df_recency.columns = ['Name', 'Date']
recent_date = df_recency['Date'].max()
df_recency['Recency'] = df_recency['Date'].apply(
    lambda x: (recent_date - x).days)
df_recency.head()
# Out:
#      Name       Date  Recency
# 0  #10000 2017-10-27     1140
# 1  #10001 2017-10-27     1140
# 2  #10002 2017-10-27     1140
# 3  #10003 2017-10-27     1140
# 4  #10004 2017-10-27     1140

# %%
frequency_df = df.drop_duplicates().groupby(
    by=['Name'], as_index=False)['Created_Date'].count()
frequency_df.columns = ['Name', 'Frequency']
frequency_df.head()
# Out:
#      Name  Frequency
# 0  #10000          1
# 1  #10001          1
# 2  #10002          1
# 3  #10003          1
# 4  #10004          1

# %%
df['Phone']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Phone'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['Payment_Reference'].value_counts()
# Out:
# c15081125314711.1    1
# c11962497171500.1    1
# c11962431897644.1    1
# c11962440056876.1    1
# c11962439893036.1    1
#                     ..
# c14292901265559.1    1
# c14292937375895.1    1
# c14292938424471.1    1
# c14280687845527.1    1
# c6688979207.1        1
# Name: Payment_Reference, Length: 95425, dtype: int64

# %%
import datetime as dt
Latest_Date = dt.datetime(2020,12,10)

# %%
RFMScores = df.groupby('Name').agg({'Date': lambda x: (Latest_Date - x.max()).days, 'Payment_Reference': lambda x: len(x), 'Total': lambda x: x.sum()})

# %%
df['Date'].fillna(method='ffill',inplace= True)

# %%
df['Billing_Zip'].fillna(method='ffill',inplace= True)

# %%
RFMScores = df.groupby('Name').agg({'Date': lambda x: (Latest_Date - x.max()).days, 'Payment_Reference': lambda x: len(x), 'Total': lambda x: x.sum()})
#Rename column names to Recency, Frequency and Monetary
RFMScores.rename(columns={'Date': 'Recency', 
                         'Payment_Reference': 'Frequency', 
                         'Total': 'Monetary'}, inplace=True)

RFMScores.reset_index().head()
# Out:
#      Name  Recency  Frequency  Monetary
# 0  #10000     1140          1     14.99
# 1  #10001     1140          1     89.99
# 2  #10002     1140          1     14.99
# 3  #10003     1140          1     14.99
# 4  #10004     1140          1     69.99

# %%
RFMScores.describe()
# Out:
#             Recency  Frequency      Monetary
# count  95484.000000    95484.0  95484.000000
# mean     403.008253        1.0     58.872480
# std      405.053706        0.0     66.217577
# min        0.000000        1.0      0.000000
# 25%      138.000000        1.0     22.500000
# 50%      245.500000        1.0     36.000000
# 75%      487.000000        1.0     72.000000
# max     1802.000000        1.0   1952.900000

# %%
x = RFMScores['Recency']

ax = sns.distplot(x)
# Out:
# C:\Users\soura\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
quantiles = RFMScores.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()

# %%
#Functions to create R, F and M segments
def RScoring(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FnMScoring(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
#Calculate Add R, F and M segment value columns in the existing dataset to show R, F and M segment values
RFMScores['R'] = RFMScores['Recency'].apply(RScoring, args=('Recency',quantiles,))
RFMScores['F'] = RFMScores['Frequency'].apply(FnMScoring, args=('Frequency',quantiles,))
RFMScores['M'] = RFMScores['Monetary'].apply(FnMScoring, args=('Monetary',quantiles,))
RFMScores.head()
# Out:
#         Recency  Frequency  Monetary  R  F  M
# Name
# #10000     1140          1     14.99  4  4  4
# #10001     1140          1     89.99  4  4  1
# #10002     1140          1     14.99  4  4  4
# #10003     1140          1     14.99  4  4  4
# #10004     1140          1     69.99  4  4  2

# %%
#Calculate and Add RFMGroup value column showing combined concatenated score of RFM
RFMScores['RFMGroup'] = RFMScores.R.map(str) + RFMScores.F.map(str) + RFMScores.M.map(str)

#Calculate and Add RFMScore value column showing total sum of RFMGroup values
RFMScores['RFMScore'] = RFMScores[['R', 'F', 'M']].sum(axis = 1)
RFMScores.head(10)
# Out:
#         Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore
# Name
# #10000     1140          1     14.99  4  4  4      444        12
# #10001     1140          1     89.99  4  4  1      441         9
# #10002     1140          1     14.99  4  4  4      444        12
# #10003     1140          1     14.99  4  4  4      444        12
# #10004     1140          1     69.99  4  4  2      442        10
# #10005     1140          1     29.95  4  4  3      443        11
# #10006     1140          1     20.00  4  4  4      444        12
# #10007     1140          1     14.99  4  4  4      444        12
# #10008     1140          1    749.99  4  4  1      441         9
# #10009     1140          1     14.99  4  4  4      444        12

# %%
#Assign Loyalty Level to each customer
Loyalty_Level = ['Platinum', 'Gold', 'Silver', 'Bronze']
Score_cuts = pd.qcut(RFMScores.RFMScore, q = 4, labels = Loyalty_Level)
RFMScores['RFM_Loyalty_Level'] = Score_cuts.values
RFMScores.reset_index().head()
# Out:
#      Name  Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore  \
# 0  #10000     1140          1     14.99  4  4  4      444        12
# 1  #10001     1140          1     89.99  4  4  1      441         9
# 2  #10002     1140          1     14.99  4  4  4      444        12
# 3  #10003     1140          1     14.99  4  4  4      444        12
# 4  #10004     1140          1     69.99  4  4  2      442        10
#
#   RFM_Loyalty_Level
# 0            Bronze
# 1              Gold
# 2            Bronze
# 3            Bronze
# 4            Silver

# %%
RFMScores.sort_values('RFMScore', ascending=True).reset_index()
# Out:
#          Name  Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore  \
# 0      #61734       95          1    149.97  1  4  1      141         6
# 1      #92122       73          1     87.99  1  4  1      141         6
# 2      #92127       73          1     93.50  1  4  1      141         6
# 3      #71106       33          1    119.98  1  4  1      141         6
# 4      #82083      109          1     86.89  1  4  1      141         6
# ...       ...      ...        ...       ... .. .. ..      ...       ...
# 95479  #22194      536          1     19.99  4  4  4      444        12
# 95480  #22191      537          1     14.99  4  4  4      444        12
# 95481   #8934     1206          1     21.99  4  4  4      444        12
# 95482  #22178      537          1     19.99  4  4  4      444        12
# 95483  #10000     1140          1     14.99  4  4  4      444        12
#
#       RFM_Loyalty_Level
# 0              Platinum
# 1              Platinum
# 2              Platinum
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
plt.xticks(rotation=90)

sns.countplot(x="RFMScore", data=RFMScores, color='steelblue', ax=ax[0])
sns.countplot(x="RFMGroup", data=RFMScores, color='steelblue', ax=ax[1])
# Out:
# <AxesSubplot:xlabel='RFMGroup', ylabel='count'>

# %%
sns.barplot(x='RFM_Loyalty_Level',y='RFMScore',data=RFMScores)
# Out:
# <AxesSubplot:xlabel='RFM_Loyalty_Level', ylabel='RFMScore'>

# %%
sns.countplot(x='RFM_Loyalty_Level', data=RFMScores, palette=palette)
xti
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11320/3306174043.py in <module>
# ----> 1 sns.countplot(x='RFM_Loyalty_Level', data=RFMScores, palette=palette)
#       2 xti
#
# NameError: name 'palette' is not defined

# %%
a=RFMScores['RFM_Loyalty_Level'].value_counts()

# %%
a.plot(kind='pie',radius=2,autopct='%1.1f%%',shadow=True,explode=(0.1, 0.1, 0.1, 0.1))
plt.show()

# %%
# Identify the three segments again based on RFMScore (33% in each segment)
segments = [0.33, 0.66]
quantiles = RFMScores.approxQuantile("RFMScore", segments, 0)

# Assign loyalty level to each customer
loyalty_level = ['Platinum', 'Gold', 'Silver']

rfm_loyalty = (RFMScores
    .withColumn("Loyalty",
                F.when((F.col("RFMScore") <= quantiles[0]), F.lit(loyalty_level[0]))
                 .when((F.col("RFMScore") <= quantiles[1]), F.lit(loyalty_level[1]))
                 .otherwise(F.lit(loyalty_level[2]))))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11320/3202333409.py in <module>
#       1 # Identify the three segments again based on RFMScore (33% in each segment)
#       2 segments = [0.33, 0.66]
# ----> 3 quantiles = RFMScores.approxQuantile("RFMScore", segments, 0)
#       4
#       5 # Assign loyalty level to each customer
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'approxQuantile'

# %%
RFMScores
# Out:
#         Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore  \
# Name
# #10000     1140          1     14.99  4  4  4      444        12
# #10001     1140          1     89.99  4  4  1      441         9
# #10002     1140          1     14.99  4  4  4      444        12
# #10003     1140          1     14.99  4  4  4      444        12
# #10004     1140          1     69.99  4  4  2      442        10
# ...         ...        ...       ... .. .. ..      ...       ...
# #9995      1141          1     34.99  4  4  3      443        11
# #9996      1141          1    109.98  4  4  1      441         9
# #9997      1141          1      9.99  4  4  4      444        12
# #9998      1141          1    154.99  4  4  1      441         9
# #9999      1140          1     24.99  4  4  3      443        11
#
#        RFM_Loyalty_Level
# Name
# #10000            Bronze
# #10001              Gold
# #10002            Bronze
# #10003            Bronze
# #10004            Silver
# ...

# %%
RFMScore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11320/3336940309.py in <module>
# ----> 1 RFMScore
#
# NameError: name 'RFMScore' is not defined

# %%
df_t=RFMScores.groupby('RFM_Loyalty_Level').sum()

# %%
df_t
# Out:
#                     Recency  Frequency    Monetary      R       F      M  \
# RFM_Loyalty_Level
# Platinum            6356504      39129  3347871.25  66324  156516  67132
# Gold                8217922      22279  1416329.97  55377   89116  56018
# Silver              7772815      14949   501390.73  45977   59796  43717
# Bronze             16133599      19127   355787.97  70929   76508  72152
#
#                    RFMScore
# RFM_Loyalty_Level
# Platinum             289972
# Gold                 200511
# Silver               149490
# Bronze               219589

# %% [markdown]
# Customer Behaviour and potential targeting techniques for each Loyalty Level:
#
# Platinum: People in this group are more frequent buyers with average days since the last purchase is 13 and the average number of times they have transacted in the platform is about 292 times in the last 1 year. Also, their average sales value is 6.5K pounds.
# These are your most loyal customers, who bought recently, most often, and are heavy spenders. Reward these customers so that they can become an early adopter for your future products and help to promote your brand.
#
#
# Gold: This group has an average frequency of 83 times and recency of 46 days. This group is also high spenders with average sales of about 1.3K pounds.
# These are your recent customers with an average frequency and who spent a good amount. Offer membership or loyalty programs or recommend related products to upsell them and help them become your Platinum members.
#
#
# Silver: People in this group have made a transaction on the platform about 87 days ago. Their frequency and monetary values are 34 times and 644 pounds respectively.
# These are your customers who purchased a decent number of times and spent good amounts but haven’t purchased recently. Sending them personalized campaigns, offers, and product recommendations will help to reconnect with them.
#
#
# Bronze: This is the dormant group with average days since their last purchase is 193. They have transacted around 15 times in the platform with average sales of 245 pounds.
# These are customers who used to visit and purchase in your platform but haven’t been visiting recently. Bring them back with relevant promotions, and run surveys to find out what went wrong and avoid losing them to a competitor.

# %%
df['Accepts_Marketing'].count()
# Out:
# 95484

# %%
a.sum()
# Out:
# 95484

# %%
df1=pd.DataFrame(RFMScores['RFM_Loyalty_Level'])

# %%
df2=pd.DataFrame(df['Accepts_Marketing'])

# %%
frame=[df1,df2]

# %%
dfdt=pd.concat(frame,)

# %%
dfdt
# Out:
#        RFM_Loyalty_Level Accepts_Marketing
# #10000            Bronze               NaN
# #10001              Gold               NaN
# #10002            Bronze               NaN
# #10003            Bronze               NaN
# #10004            Silver               NaN
# ...                  ...               ...
# 118895               NaN               yes
# 118896               NaN               yes
# 118897               NaN               yes
# 118898               NaN                no
# 118899               NaN               yes
#
# [190968 rows x 2 columns]

# %%
data_3=pd.merge(df,RFMScores,how='inner',left_on='Name',right_on='Name')

# %%
data_3
# Out:
#          Name Financial_Status                    Paid_at Fulfillment_Status  \
# 0      #96568             paid  2020-10-12 14:22:07 +0100        unfulfilled
# 1      #96567             paid  2020-10-12 14:17:46 +0100        unfulfilled
# 2      #96566             paid  2020-10-12 14:11:13 +0100        unfulfilled
# 3      #96565             paid  2020-10-12 14:05:34 +0100        unfulfilled
# 4      #96564             paid  2020-10-12 13:56:33 +0100        unfulfilled
# ...       ...              ...                        ...                ...
# 95479   #1088             paid  2016-03-30 09:53:46 +0100          fulfilled
# 95480   #1087             paid  2016-03-29 23:06:57 +0100          fulfilled
# 95481   #1086             paid  2016-03-29 20:16:08 +0100          fulfilled
# 95482   #1085             paid  2016-03-29 15:10:11 +0100          fulfilled
# 95483   #1031         refunded  2016-03-22 15:13:27 +0000        unfulfilled
#
# ...

# %%
data_3['Accepts_Marketing'],['RFM_Loyalty_Level']
# Out:
# (0         no
#  1         no
#  2         no
#  3         no
#  4         no
#          ...
#  95479    yes
#  95480    yes
#  95481    yes
#  95482     no
#  95483    yes
#  Name: Accepts_Marketing, Length: 95484, dtype: object,
#  ['RFM_Loyalty_Level'])
